# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Import citipy to determine the cities based on latitude and longitude
# from citipy import citipy

# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.12/site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.12/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#Test your API key
print(weather_api_key)
# Out:
# 6bd502b1c1153abfc05a5d610f88f638

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}" 

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]    
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        # Append the City information into city_data list
        city_data.append({
            "City": city,              
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
            })

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found ({city}) Skipping... Error: {e}")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ust-nera
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | sittwe
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | nova sintra
# Processing Record 6 of Set 1 | motygino
# Processing Record 7 of Set 1 | nadym
# Processing Record 8 of Set 1 | severo-yeniseyskiy
# Processing Record 9 of Set 1 | rumuruti
# Processing Record 10 of Set 1 | opuwo
# Processing Record 11 of Set 1 | pandan
# Processing Record 12 of Set 1 | camocim
# Processing Record 13 of Set 1 | hawaiian paradise park
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | chilecito
# Processing Record 16 of Set 1 | aasiaat
# Processing Record 17 of Set 1 | qusmuryn
# Processing Record 18 of Set 1 | port saint john's
# Processing Record 19 of Set 1 | sisimiut
# Processing Record 20 of Set 1 | sabang
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | ulanhot
# Processing Record 23 of Set 1 | adamstown
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | xiaoweizhai
# Processing Record 27 of Set 1 | chibougamau
# Processing Record 28 of Set 1 | san antonio del estrecho
# City not found (san antonio del estrecho) Skipping... Error: 'coord'
# Processing Record 29 of Set 1 | puerto natales
# Processing Record 30 of Set 1 | rio grande
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | margaret river
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | alofi
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | kujang-up
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | tabou
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | lorengau
# Processing Record 41 of Set 1 | markaz-e hukumat-e darweshan
# Processing Record 42 of Set 1 | udachny
# Processing Record 43 of Set 1 | edinburgh of the seven seas
# Processing Record 44 of Set 1 | prince george
# Processing Record 45 of Set 1 | lichuan
# Processing Record 46 of Set 1 | nytva
# Processing Record 47 of Set 1 | buritis
# Processing Record 48 of Set 1 | waitangi
# Processing Record 49 of Set 1 | arteaga
# Processing Record 50 of Set 1 | mokrous
# Processing Record 0 of Set 2 | ilulissat
# Processing Record 1 of Set 2 | invercargill
# Processing Record 2 of Set 2 | ghanzi
# Processing Record 3 of Set 2 | garoowe
# Processing Record 4 of Set 2 | stanley
# Processing Record 5 of Set 2 | port-aux-francais
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | maunabo
# Processing Record 8 of Set 2 | akjoujt
# Processing Record 9 of Set 2 | minas de marcona
# Processing Record 10 of Set 2 | kristiansund
# Processing Record 11 of Set 2 | taiohae
# City not found (taiohae) Skipping... Error: 'coord'
# Processing Record 12 of Set 2 | akureyri
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | mount isa
# Processing Record 16 of Set 2 | hamilton
# Processing Record 17 of Set 2 | santa ines
# Processing Record 18 of Set 2 | sinabang
# Processing Record 19 of Set 2 | upington
# Processing Record 20 of Set 2 | port mathurin
# Processing Record 21 of Set 2 | kalianget
# Processing Record 22 of Set 2 | caluula
# Processing Record 23 of Set 2 | tokar
# Processing Record 24 of Set 2 | anadyr
# Processing Record 25 of Set 2 | duekoue
# Processing Record 26 of Set 2 | as sulayyil
# Processing Record 27 of Set 2 | katsuura
# Processing Record 28 of Set 2 | west island
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | namibe
# Processing Record 31 of Set 2 | klyuchi
# Processing Record 32 of Set 2 | fale old settlement
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | qaqortoq
# Processing Record 35 of Set 2 | mermoz boabab
# Processing Record 36 of Set 2 | pauini
# Processing Record 37 of Set 2 | ascension
# Processing Record 38 of Set 2 | siwa oasis
# Processing Record 39 of Set 2 | poronaysk
# Processing Record 40 of Set 2 | sihanoukville
# Processing Record 41 of Set 2 | asau
# Processing Record 42 of Set 2 | hadibu
# Processing Record 43 of Set 2 | kashmor
# Processing Record 44 of Set 2 | remire-montjoly
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | flying fish cove
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | piacabucu
# Processing Record 0 of Set 3 | ciudad del maiz
# Processing Record 1 of Set 3 | keetmanshoop
# Processing Record 2 of Set 3 | holualoa
# Processing Record 3 of Set 3 | progreso
# Processing Record 4 of Set 3 | bardai
# Processing Record 5 of Set 3 | karratha
# Processing Record 6 of Set 3 | thunder bay
# Processing Record 7 of Set 3 | howard springs
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | sitka
# Processing Record 10 of Set 3 | magadan
# Processing Record 11 of Set 3 | papatowai
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | general jose de san martin
# Processing Record 15 of Set 3 | st. john's
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | kerikeri
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | santa ana
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | ornskoldsvik
# Processing Record 22 of Set 3 | palikir - national government center
# Processing Record 23 of Set 3 | chatillon-sur-seine
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | zhangye
# Processing Record 26 of Set 3 | hotan
# Processing Record 27 of Set 3 | christchurch
# Processing Record 28 of Set 3 | la'ie
# Processing Record 29 of Set 3 | coahuayana de hidalgo
# Processing Record 30 of Set 3 | olonkinbyen
# Processing Record 31 of Set 3 | zambezi
# Processing Record 32 of Set 3 | kokopo
# Processing Record 33 of Set 3 | georgetown
# Processing Record 34 of Set 3 | ternate
# Processing Record 35 of Set 3 | hirosaki
# Processing Record 36 of Set 3 | garagoa
# Processing Record 37 of Set 3 | lekeitio
# Processing Record 38 of Set 3 | malango
# Processing Record 39 of Set 3 | cable beach
# City not found (cable beach) Skipping... Error: 'coord'
# Processing Record 40 of Set 3 | falenki
# Processing Record 41 of Set 3 | luza
# Processing Record 42 of Set 3 | emet
# Processing Record 43 of Set 3 | bilibino
# Processing Record 44 of Set 3 | seka
# Processing Record 45 of Set 3 | brookings
# Processing Record 46 of Set 3 | badger
# Processing Record 47 of Set 3 | tazacorte
# Processing Record 48 of Set 3 | vingt cinq
# City not found (vingt cinq) Skipping... Error: 'coord'
# Processing Record 49 of Set 3 | isafjordur
# Processing Record 0 of Set 4 | dawson creek
# Processing Record 1 of Set 4 | dickinson
# Processing Record 2 of Set 4 | utrik
# Processing Record 3 of Set 4 | rehoboth
# Processing Record 4 of Set 4 | queenstown
# Processing Record 5 of Set 4 | sumbawa besar
# Processing Record 6 of Set 4 | adh dhibiyah
# Processing Record 7 of Set 4 | vohipaho
# City not found (vohipaho) Skipping... Error: 'coord'
# Processing Record 8 of Set 4 | cargados carajos
# City not found (cargados carajos) Skipping... Error: 'coord'
# Processing Record 9 of Set 4 | usinsk
# Processing Record 10 of Set 4 | dudinka
# Processing Record 11 of Set 4 | punta arenas
# Processing Record 12 of Set 4 | ahau
# City not found (ahau) Skipping... Error: 'coord'
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | ushuaia
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | polonne
# Processing Record 17 of Set 4 | shubarshi
# Processing Record 18 of Set 4 | manokwari
# Processing Record 19 of Set 4 | inhambane
# Processing Record 20 of Set 4 | colonia
# Processing Record 21 of Set 4 | ola
# Processing Record 22 of Set 4 | korla
# Processing Record 23 of Set 4 | mukah
# City not found (mukah) Skipping... Error: 'coord'
# Processing Record 24 of Set 4 | san luis
# Processing Record 25 of Set 4 | port augusta
# Processing Record 26 of Set 4 | marquette
# Processing Record 27 of Set 4 | ballina
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | kalabo
# Processing Record 30 of Set 4 | atafu village
# Processing Record 31 of Set 4 | iskateley
# Processing Record 32 of Set 4 | rongelap
# Processing Record 33 of Set 4 | vorgashor
# Processing Record 34 of Set 4 | nuuk
# Processing Record 35 of Set 4 | pathein
# Processing Record 36 of Set 4 | lazaro cardenas
# Processing Record 37 of Set 4 | magor
# Processing Record 38 of Set 4 | sao gabriel da cachoeira
# Processing Record 39 of Set 4 | jinghong
# Processing Record 40 of Set 4 | shiqian
# Processing Record 41 of Set 4 | mazagao
# Processing Record 42 of Set 4 | freetown
# Processing Record 43 of Set 4 | fort mcmurray
# Processing Record 44 of Set 4 | ibeto
# Processing Record 45 of Set 4 | salinas
# Processing Record 46 of Set 4 | la passe
# Processing Record 47 of Set 4 | chonchi
# Processing Record 48 of Set 4 | uturoa
# Processing Record 49 of Set 4 | lucas
# Processing Record 0 of Set 5 | cidreira
# Processing Record 1 of Set 5 | ambalangoda
# Processing Record 2 of Set 5 | dryden
# Processing Record 3 of Set 5 | santo antonio
# Processing Record 4 of Set 5 | wuzhou
# Processing Record 5 of Set 5 | zhanibek
# Processing Record 6 of Set 5 | livramento do brumado
# Processing Record 7 of Set 5 | porto murtinho
# Processing Record 8 of Set 5 | gulf shores
# Processing Record 9 of Set 5 | soio
# Processing Record 10 of Set 5 | kapa'a
# Processing Record 11 of Set 5 | amnat charoen
# Processing Record 12 of Set 5 | karatas
# Processing Record 13 of Set 5 | conde
# Processing Record 14 of Set 5 | conselheiro lafaiete
# Processing Record 15 of Set 5 | tolanaro
# Processing Record 16 of Set 5 | sal rei
# Processing Record 17 of Set 5 | suva
# Processing Record 18 of Set 5 | fort bragg
# Processing Record 19 of Set 5 | santa elena de uairen
# Processing Record 20 of Set 5 | greenville
# Processing Record 21 of Set 5 | puerto colombia
# Processing Record 22 of Set 5 | gadzhiyevo
# Processing Record 23 of Set 5 | maloye ganyushkino
# Processing Record 24 of Set 5 | maragogi
# Processing Record 25 of Set 5 | zhanaozen
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | kirakira
# Processing Record 28 of Set 5 | ormara
# Processing Record 29 of Set 5 | folkston
# Processing Record 30 of Set 5 | walvis bay
# Processing Record 31 of Set 5 | kalifornsky
# Processing Record 32 of Set 5 | tralee
# Processing Record 33 of Set 5 | wailua homesteads
# Processing Record 34 of Set 5 | shantobe
# Processing Record 35 of Set 5 | la calera
# Processing Record 36 of Set 5 | olyokminsk
# Processing Record 37 of Set 5 | abancay
# Processing Record 38 of Set 5 | kodiak
# Processing Record 39 of Set 5 | taghazout
# Processing Record 40 of Set 5 | vadso
# Processing Record 41 of Set 5 | saint-felicien
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | pervomayskoye
# Processing Record 44 of Set 5 | yangor
# City not found (yangor) Skipping... Error: 'coord'
# Processing Record 45 of Set 5 | newman
# Processing Record 46 of Set 5 | arvika
# Processing Record 47 of Set 5 | kohtla-jarve
# Processing Record 48 of Set 5 | lihue
# Processing Record 49 of Set 5 | melfort
# Processing Record 0 of Set 6 | celestun
# Processing Record 1 of Set 6 | seydi
# Processing Record 2 of Set 6 | plouzane
# Processing Record 3 of Set 6 | borazjan
# Processing Record 4 of Set 6 | saipan
# Processing Record 5 of Set 6 | polyarnyy
# Processing Record 6 of Set 6 | tobi village
# City not found (tobi village) Skipping... Error: 'coord'
# Processing Record 7 of Set 6 | birnin kudu
# Processing Record 8 of Set 6 | sungailiat
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | lebu
# Processing Record 11 of Set 6 | jiuquan
# Processing Record 12 of Set 6 | hasaki
# Processing Record 13 of Set 6 | zanesville
# Processing Record 14 of Set 6 | flin flon
# Processing Record 15 of Set 6 | buka
# Processing Record 16 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 6 | mwinilunga
# Processing Record 18 of Set 6 | chinsali
# Processing Record 19 of Set 6 | tateyama
# Processing Record 20 of Set 6 | yangambi
# Processing Record 21 of Set 6 | benguela
# Processing Record 22 of Set 6 | concepcion de la sierra
# Processing Record 23 of Set 6 | okhotsk
# Processing Record 24 of Set 6 | leticia
# Processing Record 25 of Set 6 | spas-klepiki
# Processing Record 26 of Set 6 | longyearbyen
# Processing Record 27 of Set 6 | beyneu
# Processing Record 28 of Set 6 | coquimbo
# Processing Record 29 of Set 6 | hammerfest
# Processing Record 30 of Set 6 | ocos
# Processing Record 31 of Set 6 | kone
# Processing Record 32 of Set 6 | tsiombe
# Processing Record 33 of Set 6 | nieuw amsterdam
# Processing Record 34 of Set 6 | bandiagara
# Processing Record 35 of Set 6 | alice springs
# Processing Record 36 of Set 6 | salekhard
# Processing Record 37 of Set 6 | vilyuysk
# Processing Record 38 of Set 6 | ashburton
# Processing Record 39 of Set 6 | goz beida
# Processing Record 40 of Set 6 | tangalle
# Processing Record 41 of Set 6 | chernyshevsk
# Processing Record 42 of Set 6 | santana
# Processing Record 43 of Set 6 | yarmouth
# Processing Record 44 of Set 6 | whitehorse
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | antigonish
# Processing Record 47 of Set 6 | tvoroyri
# Processing Record 48 of Set 6 | naze
# Processing Record 49 of Set 6 | arar
# Processing Record 0 of Set 7 | pariaman
# Processing Record 1 of Set 7 | kingston
# Processing Record 2 of Set 7 | gressier
# Processing Record 3 of Set 7 | hithadhoo
# Processing Record 4 of Set 7 | talas
# Processing Record 5 of Set 7 | niafunke
# Processing Record 6 of Set 7 | magway
# Processing Record 7 of Set 7 | gamba
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | tuy hoa
# Processing Record 10 of Set 7 | vorkuta
# Processing Record 11 of Set 7 | barauna
# Processing Record 12 of Set 7 | fuyuan
# Processing Record 13 of Set 7 | carolina beach
# Processing Record 14 of Set 7 | lewiston orchards
# Processing Record 15 of Set 7 | los alamos
# Processing Record 16 of Set 7 | east london
# Processing Record 17 of Set 7 | tranovaho
# City not found (tranovaho) Skipping... Error: 'coord'
# Processing Record 18 of Set 7 | alotau
# Processing Record 19 of Set 7 | mahad
# Processing Record 20 of Set 7 | ariquemes
# Processing Record 21 of Set 7 | san antonio de pale
# Processing Record 22 of Set 7 | ar rutbah
# Processing Record 23 of Set 7 | kibaya
# Processing Record 24 of Set 7 | valparaiso
# Processing Record 25 of Set 7 | swan hill
# Processing Record 26 of Set 7 | holbrook
# Processing Record 27 of Set 7 | sirmaur
# Processing Record 28 of Set 7 | kamaishi
# Processing Record 29 of Set 7 | nabire
# Processing Record 30 of Set 7 | caconda
# Processing Record 31 of Set 7 | waimea
# Processing Record 32 of Set 7 | fallon
# Processing Record 33 of Set 7 | fehrbellin
# Processing Record 34 of Set 7 | bosaso
# Processing Record 35 of Set 7 | nogliki
# Processing Record 36 of Set 7 | turkmenbasy
# Processing Record 37 of Set 7 | mahabaleshwar
# Processing Record 38 of Set 7 | ishigaki
# Processing Record 39 of Set 7 | wenatchee
# Processing Record 40 of Set 7 | oriximina
# Processing Record 41 of Set 7 | taoudenni
# Processing Record 42 of Set 7 | san antonio oeste
# Processing Record 43 of Set 7 | ghadamis
# Processing Record 44 of Set 7 | paita
# Processing Record 45 of Set 7 | saltillo
# Processing Record 46 of Set 7 | murghob
# Processing Record 47 of Set 7 | bodaybo
# Processing Record 48 of Set 7 | kinablangan
# Processing Record 49 of Set 7 | montana
# Processing Record 0 of Set 8 | bouza
# Processing Record 1 of Set 8 | afaahiti
# Processing Record 2 of Set 8 | midvagur
# Processing Record 3 of Set 8 | westport
# Processing Record 4 of Set 8 | hastings
# Processing Record 5 of Set 8 | inverness
# Processing Record 6 of Set 8 | wanganui
# Processing Record 7 of Set 8 | tsengel
# Processing Record 8 of Set 8 | hinton
# Processing Record 9 of Set 8 | el granada
# Processing Record 10 of Set 8 | ammon
# Processing Record 11 of Set 8 | dalhart
# Processing Record 12 of Set 8 | bikenibeu village
# Processing Record 13 of Set 8 | charters towers
# Processing Record 14 of Set 8 | pimentel
# Processing Record 15 of Set 8 | quellon
# Processing Record 16 of Set 8 | dunedin
# Processing Record 17 of Set 8 | haiku-pauwela
# Processing Record 18 of Set 8 | itoman
# Processing Record 19 of Set 8 | mbanga
# Processing Record 20 of Set 8 | laramie
# Processing Record 21 of Set 8 | nemuro
# Processing Record 22 of Set 8 | gizo
# Processing Record 23 of Set 8 | novodvinsk
# Processing Record 24 of Set 8 | machali
# Processing Record 25 of Set 8 | al jawf
# Processing Record 26 of Set 8 | estella-lizarra
# Processing Record 27 of Set 8 | pernio
# Processing Record 28 of Set 8 | rundu
# Processing Record 29 of Set 8 | manzhouli
# Processing Record 30 of Set 8 | fernie
# Processing Record 31 of Set 8 | yamada
# Processing Record 32 of Set 8 | mahina
# Processing Record 33 of Set 8 | mejit
# Processing Record 34 of Set 8 | ribeira brava
# Processing Record 35 of Set 8 | northam
# Processing Record 36 of Set 8 | 'ohonua
# City not found ('ohonua) Skipping... Error: 'coord'
# Processing Record 37 of Set 8 | bargara
# City not found (bargara) Skipping... Error: 'coord'
# Processing Record 38 of Set 8 | somers point
# Processing Record 39 of Set 8 | tawau
# Processing Record 40 of Set 8 | lerwick
# Processing Record 41 of Set 8 | kalmunai
# Processing Record 42 of Set 8 | coxen hole
# Processing Record 43 of Set 8 | itai
# Processing Record 44 of Set 8 | mount pleasant
# Processing Record 45 of Set 8 | chengde
# Processing Record 46 of Set 8 | kavieng
# Processing Record 47 of Set 8 | sampit
# Processing Record 48 of Set 8 | ad-damazin
# Processing Record 49 of Set 8 | aurangabad
# Processing Record 0 of Set 9 | vanimo
# Processing Record 1 of Set 9 | happy valley-goose bay
# Processing Record 2 of Set 9 | susuman
# Processing Record 3 of Set 9 | mansa
# Processing Record 4 of Set 9 | manuguru
# Processing Record 5 of Set 9 | crane
# Processing Record 6 of Set 9 | vernon
# Processing Record 7 of Set 9 | ifanadiana
# Processing Record 8 of Set 9 | al khums
# Processing Record 9 of Set 9 | novyy turtkul'
# Processing Record 10 of Set 9 | solikamsk
# Processing Record 11 of Set 9 | shalqar
# Processing Record 12 of Set 9 | garachico
# Processing Record 13 of Set 9 | touros
# Processing Record 14 of Set 9 | klaksvik
# Processing Record 15 of Set 9 | sarospatak
# Processing Record 16 of Set 9 | abasolo
# Processing Record 17 of Set 9 | rahuri
# Processing Record 18 of Set 9 | marka
# Processing Record 19 of Set 9 | nar'yan-mar
# Processing Record 20 of Set 9 | carutapera
# Processing Record 21 of Set 9 | ishinomaki
# Processing Record 22 of Set 9 | punta del este
# Processing Record 23 of Set 9 | cururupu
# Processing Record 24 of Set 9 | lionel town
# Processing Record 25 of Set 9 | ghat
# Processing Record 26 of Set 9 | anbu
# Processing Record 27 of Set 9 | alto barinas
# Processing Record 28 of Set 9 | the bottom
# Processing Record 29 of Set 9 | antsiranana
# Processing Record 30 of Set 9 | ayaguz
# City not found (ayaguz) Skipping... Error: 'coord'
# Processing Record 31 of Set 9 | challapata
# Processing Record 32 of Set 9 | zakynthos
# Processing Record 33 of Set 9 | bude
# Processing Record 34 of Set 9 | oranjemund
# Processing Record 35 of Set 9 | ambon
# Processing Record 36 of Set 9 | xilin hot
# Processing Record 37 of Set 9 | markovo
# Processing Record 38 of Set 9 | tataouine
# Processing Record 39 of Set 9 | st. paul
# Processing Record 40 of Set 9 | vilyuchinsk
# Processing Record 41 of Set 9 | fuvahmulah
# City not found (fuvahmulah) Skipping... Error: 'coord'
# Processing Record 42 of Set 9 | zhob
# Processing Record 43 of Set 9 | ivins
# Processing Record 44 of Set 9 | nkove
# Processing Record 45 of Set 9 | mareeba
# Processing Record 46 of Set 9 | iowa falls
# Processing Record 47 of Set 9 | glace bay
# Processing Record 48 of Set 9 | lospalos
# Processing Record 49 of Set 9 | asubulaq
# Processing Record 0 of Set 10 | san jose village
# City not found (san jose village) Skipping... Error: 'coord'
# Processing Record 1 of Set 10 | tura
# Processing Record 2 of Set 10 | sarandi del yi
# Processing Record 3 of Set 10 | san sebastian de la gomera
# Processing Record 4 of Set 10 | puerto san carlos
# City not found (puerto san carlos) Skipping... Error: 'coord'
# Processing Record 5 of Set 10 | gaspe
# Processing Record 6 of Set 10 | gambela
# Processing Record 7 of Set 10 | dhidhdhoo
# Processing Record 8 of Set 10 | novyy urgal
# Processing Record 9 of Set 10 | kaa-khem
# Processing Record 10 of Set 10 | nova vicosa
# Processing Record 11 of Set 10 | vila velha
# Processing Record 12 of Set 10 | belyy yar
# Processing Record 13 of Set 10 | vila franca do campo
# Processing Record 14 of Set 10 | malabar
# Processing Record 15 of Set 10 | isiro
# Processing Record 16 of Set 10 | slave lake
# Processing Record 17 of Set 10 | egilsstadir
# Processing Record 18 of Set 10 | keflavik
# Processing Record 19 of Set 10 | trinity beach
# Processing Record 20 of Set 10 | rechka-vydrino
# Processing Record 21 of Set 10 | enewetak
# Processing Record 22 of Set 10 | kapuskasing
# Processing Record 23 of Set 10 | muli
# Processing Record 24 of Set 10 | puerto deseado
# Processing Record 25 of Set 10 | praia da vitoria
# Processing Record 26 of Set 10 | sharypovo
# Processing Record 27 of Set 10 | lautoka
# Processing Record 28 of Set 10 | leava
# Processing Record 29 of Set 10 | gapyeong
# Processing Record 30 of Set 10 | dakhla
# Processing Record 31 of Set 10 | broken hill
# Processing Record 32 of Set 10 | constantia
# Processing Record 33 of Set 10 | reggane
# Processing Record 34 of Set 10 | zav'yalovo
# Processing Record 35 of Set 10 | moyale
# Processing Record 36 of Set 10 | kasane
# Processing Record 37 of Set 10 | papao
# Processing Record 38 of Set 10 | jalapa
# Processing Record 39 of Set 10 | portland
# Processing Record 40 of Set 10 | taroa
# Processing Record 41 of Set 10 | lithgow
# Processing Record 42 of Set 10 | ati
# Processing Record 43 of Set 10 | vanino
# Processing Record 44 of Set 10 | brady
# Processing Record 45 of Set 10 | zaozersk
# Processing Record 46 of Set 10 | vuktyl
# Processing Record 47 of Set 10 | puerto el triunfo
# Processing Record 48 of Set 10 | barreirinha
# Processing Record 49 of Set 10 | ciudad lazaro cardenas
# Processing Record 0 of Set 11 | labrador city
# Processing Record 1 of Set 11 | esperantinopolis
# Processing Record 2 of Set 11 | gereida
# Processing Record 3 of Set 11 | general conesa
# Processing Record 4 of Set 11 | filadelfia
# Processing Record 5 of Set 11 | abepura
# Processing Record 6 of Set 11 | surazh
# Processing Record 7 of Set 11 | ushirombo
# Processing Record 8 of Set 11 | kabalo
# Processing Record 9 of Set 11 | al burayqah
# Processing Record 10 of Set 11 | bambanglipuro
# Processing Record 11 of Set 11 | tomatlan
# Processing Record 12 of Set 11 | fort st. john
# Processing Record 13 of Set 11 | puerto baquerizo moreno
# Processing Record 14 of Set 11 | san julian
# Processing Record 15 of Set 11 | meadow lake
# Processing Record 16 of Set 11 | hoemul-li
# Processing Record 17 of Set 11 | bubaque
# Processing Record 18 of Set 11 | mitsamiouli
# Processing Record 19 of Set 11 | khorinsk
# Processing Record 20 of Set 11 | chincha alta
# Processing Record 21 of Set 11 | jolo
# Processing Record 22 of Set 11 | kavaratti
# Processing Record 23 of Set 11 | sarmiento
# Processing Record 24 of Set 11 | lompoc
# Processing Record 25 of Set 11 | segarcea
# Processing Record 26 of Set 11 | ahrensbok
# Processing Record 27 of Set 11 | chimbarongo
# Processing Record 28 of Set 11 | guichon
# Processing Record 29 of Set 11 | las palmas
# Processing Record 30 of Set 11 | mafeteng
# Processing Record 31 of Set 11 | mata-utu
# Processing Record 32 of Set 11 | joao pinheiro
# Processing Record 33 of Set 11 | al muwayh
# Processing Record 34 of Set 11 | barda
# Processing Record 35 of Set 11 | acarau
# Processing Record 36 of Set 11 | yashan
# Processing Record 37 of Set 11 | nguigmi
# Processing Record 38 of Set 11 | floro
# Processing Record 39 of Set 11 | swakopmund
# Processing Record 40 of Set 11 | paphos
# Processing Record 41 of Set 11 | bonthe
# Processing Record 42 of Set 11 | kataragama
# City not found (kataragama) Skipping... Error: 'coord'
# Processing Record 43 of Set 11 | haenam
# Processing Record 44 of Set 11 | jayapura
# Processing Record 45 of Set 11 | acajutla
# Processing Record 46 of Set 11 | laojunmiao
# Processing Record 47 of Set 11 | luanco
# Processing Record 48 of Set 11 | zapolyarnyy
# Processing Record 49 of Set 11 | al bawiti
# Processing Record 0 of Set 12 | byron bay
# Processing Record 1 of Set 12 | larkird
# Processing Record 2 of Set 12 | le port
# Processing Record 3 of Set 12 | kemi
# Processing Record 4 of Set 12 | choix
# Processing Record 5 of Set 12 | mogocha
# Processing Record 6 of Set 12 | hihifo
# City not found (hihifo) Skipping... Error: 'coord'
# Processing Record 7 of Set 12 | san pedro piedra gorda
# Processing Record 8 of Set 12 | bechar
# Processing Record 9 of Set 12 | leninskoye
# Processing Record 10 of Set 12 | forster
# Processing Record 11 of Set 12 | gorontalo
# Processing Record 12 of Set 12 | kyabram
# Processing Record 13 of Set 12 | el calafate
# Processing Record 14 of Set 12 | longgang
# Processing Record 15 of Set 12 | arroyo seco
# Processing Record 16 of Set 12 | george town
# Processing Record 17 of Set 12 | porto tolle
# Processing Record 18 of Set 12 | chasong
# Processing Record 19 of Set 12 | nikolayevsk-on-amure
# Processing Record 20 of Set 12 | undurkhaan
# Processing Record 21 of Set 12 | igoumenitsa
# Processing Record 22 of Set 12 | barranquilla
# Processing Record 23 of Set 12 | vallenar
# Processing Record 24 of Set 12 | dzhangala
# Processing Record 25 of Set 12 | saint-marcel
# Processing Record 26 of Set 12 | polovinnoye
# Processing Record 27 of Set 12 | sandnessjoen
# Processing Record 28 of Set 12 | mandalgovi
# Processing Record 29 of Set 12 | douglas
# Processing Record 30 of Set 12 | sao vicente
# Processing Record 31 of Set 12 | kurmuk
# Processing Record 32 of Set 12 | bac lieu
# Processing Record 33 of Set 12 | natal
# Processing Record 34 of Set 12 | el charco
# Processing Record 35 of Set 12 | altpinar
# Processing Record 36 of Set 12 | ningyang
# Processing Record 37 of Set 12 | belmonte
# Processing Record 38 of Set 12 | usogorsk
# Processing Record 39 of Set 12 | hirara
# Processing Record 40 of Set 12 | kailua-kona
# Processing Record 41 of Set 12 | ytyk-kyuyel'
# City not found (ytyk-kyuyel') Skipping... Error: 'coord'
# Processing Record 42 of Set 12 | paidha
# Processing Record 43 of Set 12 | cannonvale
# Processing Record 44 of Set 12 | nantucket
# Processing Record 45 of Set 12 | magalia
# Processing Record 46 of Set 12 | xylofagou
# Processing Record 47 of Set 12 | qinzhou
# Processing Record 48 of Set 12 | selkirk
# Processing Record 49 of Set 12 | midoun
# Processing Record 0 of Set 13 | stephenville
# Processing Record 1 of Set 13 | sinan
# Processing Record 2 of Set 13 | tumpat
# Processing Record 3 of Set 13 | yazykovo
# Processing Record 4 of Set 13 | mumford
# Processing Record 5 of Set 13 | phanom sarakham
# Processing Record 6 of Set 13 | alpena
# Processing Record 7 of Set 13 | bireun
# Processing Record 8 of Set 13 | ust'-barguzin
# Processing Record 9 of Set 13 | mossendjo
# Processing Record 10 of Set 13 | westhill
# Processing Record 11 of Set 13 | erdenet
# Processing Record 12 of Set 13 | el porvenir
# Processing Record 13 of Set 13 | el obeid
# Processing Record 14 of Set 13 | alamogordo
# Processing Record 15 of Set 13 | kendari
# Processing Record 16 of Set 13 | agat village
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Double check the number of cities in the list to make sure its been appended.

print(len(city_data))
# Out:
# 597

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ust-nera  64.5667  143.2000    -19.69        87          59
# 1      grytviken -54.2811  -36.5092      3.11        90          62
# 2         sittwe  20.1500   92.9000     25.27        78          54
# 3  blackmans bay -43.0167  147.3167     28.74        32         100
# 4    nova sintra  14.8667  -24.7167     20.70        80           0
#
#    Wind Speed Country        Date
# 0        0.47      RU  1742435582
# 1        1.98      GS  1742435583
# 2        1.43      MM  1742435585
# 3        0.89      AU  1742435586
# 4       12.04      CV  1742435587

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ust-nera  64.5667  143.2000    -19.69        87          59
# 1      grytviken -54.2811  -36.5092      3.11        90          62
# 2         sittwe  20.1500   92.9000     25.27        78          54
# 3  blackmans bay -43.0167  147.3167     28.74        32         100
# 4    nova sintra  14.8667  -24.7167     20.70        80           0
#
#    Wind Speed Country        Date
# 0        0.47      RU  1742435582
# 1        1.98      GS  1742435583
# 2        1.43      MM  1742435585
# 3        0.89      AU  1742435586
# 4       12.04      CV  1742435587

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../python-api-challenge/City_Data.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../python-api-challenge/City_Data.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             ust-nera  64.5667  143.2000    -19.69        87          59
# 1            grytviken -54.2811  -36.5092      3.11        90          62
# 2               sittwe  20.1500   92.9000     25.27        78          54
# 3        blackmans bay -43.0167  147.3167     28.74        32         100
# 4          nova sintra  14.8667  -24.7167     20.70        80           0
#
#          Wind Speed Country        Date
# City_ID
# 0              0.47      RU  1742435582
# 1              1.98      GS  1742435583
# 2              1.43      MM  1742435585
# 3              0.89      AU  1742435586
# 4             12.04      CV  1742435587

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

lat_temp_scatter = plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors = "black", facecolors = "red")

# Incorporate the other graph properties

plt.title("City Max Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid (axis = "both", color = "gray", linewidth = 0.25, linestyle = "-")

# Save the figure
plt.savefig("../python-api-challenge/output_data/Lat_Temp_ScatterPlot.png")

plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for Latitude vs. Humidity

lat_humidity_scatter = plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors = "black", facecolors = "red")

# Incorporate the other graph properties

plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")  
plt.grid (axis = "both", color = "gray", linewidth = 0.25, linestyle = "-")

# Save the figure
plt.savefig("../python-api-challenge/output_data/Lat_Humidity_ScatterPlot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_cloudiness_scatter = plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors = "black", facecolors = "red")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")  
plt.grid (axis = "both", color = "gray", linewidth = 0.25, linestyle = "-")

# Save the figure
plt.savefig("../python-api-challenge/output_data/Lat_Cloudiness_ScatterPlot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_windspeed_scatter = plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors = "black", facecolors = "red")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")  
plt.grid (axis = "both", color = "gray", linewidth = 0.25, linestyle = "-")

# Save the figure
plt.savefig("../python-api-challenge/output_data/Lat_WindSpeed_ScatterPlot.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates):
    
    #Compute the linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    #Compute the regression values
    regress_values = x_values * slope + intercept

    #Format it to display only two decimal places
    line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
    
    #Create the plot
    plt.scatter(x_values, y_values, edgecolors="black", facecolors="skyblue")
    plt.plot(x_values, regress_values, "r-", label=line_eq)
    plt.annotate(line_eq, text_coordinates, fontsize=12, color="red")

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    print(f"The r-squared is: {rvalue**2:.3f}")
    
    plt.show()

    return rvalue

# %%
#Test the function with some sample data. 

x_test = np.random.uniform(-90, 90, 1500)
y_test = np.random.uniform(-90, 90, 1500)

test_plot_linear_regression = linear_regression(x_test, y_test, "x", "y", "Test Linear Regression", (-50, 50))
# Out:
# The r-squared is: 0.003

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemisphere_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           ust-nera  64.5667  143.2000    -19.69        87          59
# 2             sittwe  20.1500   92.9000     25.27        78          54
# 4        nova sintra  14.8667  -24.7167     20.70        80           0
# 5           motygino  58.1831   94.7592      1.30        95         100
# 6              nadym  65.5333   72.5167    -12.84        96          57
#
#          Wind Speed Country        Date
# City_ID
# 0              0.47      RU  1742435582
# 2              1.43      MM  1742435585
# 4             12.04      CV  1742435587
# 5              3.97      RU  1742435588
# 6              6.27      RU  1742435589

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemisphere_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemisphere_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            grytviken -54.2811  -36.5092      3.11        90          62
# 3        blackmans bay -43.0167  147.3167     28.74        32         100
# 9                opuwo -18.0607   13.8400     18.66        96          98
# 11             camocim  -2.9022  -40.8411     24.81        88          97
# 13          bredasdorp -34.5322   20.0403     19.98        79           0
#
#          Wind Speed Country        Date
# City_ID
# 1              1.98      GS  1742435583
# 3              0.89      AU  1742435586
# 9              1.81     NaN  1742435593
# 11             3.01      BR  1742435595
# 13             1.47      ZA  1742435597

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
r_squared_north = linear_regression(
    northern_hemisphere_df["Lat"], northern_hemisphere_df["Max Temp"],
    "Latitude", "Max Temperature (C)",
    "Northern Hemisphere: Temperature vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_north:.3f}")
# Out:
# The r-squared is: 0.805

# %%
# Linear regression on Southern Hemisphere
r_squared_south = linear_regression(
    southern_hemisphere_df["Lat"], southern_hemisphere_df["Max Temp"],
    "Latitude", "Max Temperature (C)",
    "Southern Hemisphere: Temperature vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_south:.3f}")
# Out:
# The r-squared is: 0.261

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# As we move away from the Equator(Latitude = 0), temperatures tend to decrease. After some research, I actually found that fluctuations tend to be more moderate in the southern hemisphere due to the fact that there is less land mass and more oceans which help regulate temperature variations.
#
# A high R-sqaure value between 0.7 and 0.9 suggests a strong relationship in this regard.
#
# We can conclude latitude is a strong predictor of temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
r_squared_north = linear_regression(
    northern_hemisphere_df["Lat"], northern_hemisphere_df["Humidity"],
    "Latitude", "Humidity (%)",
    "Northern Hemisphere: Humidity vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_north:.3f}")
# Out:
# The r-squared is: 0.066

# %%
# Southern Hemisphere
r_squared_south = linear_regression(
    southern_hemisphere_df["Lat"], southern_hemisphere_df["Humidity"],
    "Latitude", "Humidity (%)",
    "Southern Hemisphere: Humidity vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_south:.3f}")
# Out:
# The r-squared is: 0.172

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# In the case of the linear relationship between latitude and humidity, the relationship is weak. This is further confirmed by the low R-squared value. Upon further analysis, I found umidity is highly dependent on local climate conditions rather than latitude. High latitude areas such as the Artic can have high humidity due to cloud cover just like places in the Equator whose warm air holds more moistuere. Coincidentially, albeit being close to the Equator, deserts can have very low humidity, further supporting this hypothesis. In conclusion, latitude alone is not a strong predictor of humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
r_squared_north = linear_regression(
    northern_hemisphere_df["Lat"], northern_hemisphere_df["Cloudiness"],
    "Latitude", "Cloudiness",
    "Northern Hemisphere: Cloudiness vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_north:.3f}")
# Out:
# The r-squared is: 0.014

# %%
# Southern Hemisphere
r_squared_south = linear_regression(
    southern_hemisphere_df["Lat"], southern_hemisphere_df["Cloudiness"],
    "Latitude", "Cloudiness",
    "Southern Hemisphere: Cloudiness vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_south:.3f}")
# Out:
# The r-squared is: 0.017

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# When it comes to the relationship between cloudiness and latitude, it also weak. This is further supported by its low R-squared value and the lack of a clear pattern in the scater plot. Upon further research, I found cloud formation is heavily influenced by local factors such as geography, air pressure and seasonal weather patterns. In conclusion, latitude is an inconsistent predictor of cloudiness in regions across the world.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
r_squared_north = linear_regression(
    northern_hemisphere_df["Lat"], northern_hemisphere_df["Wind Speed"],
    "Latitude", "Wind Speed",
    "Northern Hemisphere: Wind Speed vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_north:.3f}")
# Out:
# The r-squared is: 0.004

# %%
# Southern Hemisphere
r_squared_south = linear_regression(
    southern_hemisphere_df["Lat"], southern_hemisphere_df["Wind Speed M/S"],
    "Latitude", "Wind Speed",
    "Southern Hemisphere: Wind Speed vs. Latitude", (0, 0)
)

# Print the correct R-squared value
# print(f"R-squared value: {r_squared_south:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Southern Hemisphere
# ----> 2 r_squared_south = linear_regression(
#       3     southern_hemisphere_df["Lat"], southern_hemisphere_df["Wind Speed M/S"],
#       4     "Latitude", "Wind Speed",
#       5     "Southern Hemisphere: Wind Speed vs. Latitude", (0, 0)
#       6 )
#
# NameError: name 'linear_regression' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# Latitude alone is not a strong predictor of wind speed but the relationship tends to be a little stronger. Wind speed tends to be driven by air pressure differences as well as local geography. While a low to moderate relationship is shown, regional trends influenced by wind patterns are a stronger predictor than latitude alone.
